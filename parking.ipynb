# %%
import pandas as pd
import numpy as np

df=pd.read_csv("data/istanbulöneri_fixed.csv")
df2 = pd.read_csv("parking.csv", encoding='iso-8859-9')

# %%
import pandas as pd
import numpy as np
import json # json kütüphanesini import ediyoruz

# Bu JSON verisini bir dosyadan oku veya doğrudan kodda tut
json_data = ["{\"OTOPARK ADI\":\"Alibeyköy Cep Otogarı Otobüs Otoparkı\",\"LOKASYON ADI\":\"Alibeyköy Cep Otogarı Otobüs Otopark\",\"PARK TİPİ\":\"AÇIK OTOPARK\",\"PARK TİPİ TANIMI\":\"AÇIK OTOPARK\",\"PARK KAPASİTESİ\":5000.0,\"ÇALIŞMA ZAMANI\":\"24 Saat\",\"BULUNDUĞU İLÇE\":\"EYÜP\",\"BOYLAM\":\"28.9451551437378\",\"ENLEM\":\"41.0876321246792\"}","{\"OTOPARK ADI\":\"Alibeyköy Cep Otogarı P+R\",\"LOKASYON ADI\":\"Alibeyköy Cep Otogarı P+\",\"PARK TİPİ\":\"AÇIK OTOPARK\",\"PARK TİPİ TANIMI\":\"AÇIK OTOPARK\",\"PARK KAPASİTESİ\":88.0,\"ÇALIŞMA ZAMANI\":\"24 Saat\",\"BULUNDUĞU İLÇE\":\"EYÜP\",\"BOYLAM\":\"28.9423878505096\",\"ENLEM\":\"41.08823151328\"}","{\"OTOPARK ADI\":\"Eyüp Tekke Parkı\",\"LOKASYON ADI\":\"Eyüp Tekke Park\",\"PARK TİPİ\":\"AÇIK OTOPARK\",\"PARK TİPİ TANIMI\":\"AÇIK OTOPARK\",\"PARK KAPASİTESİ\":70.0,\"ÇALIŞMA ZAMANI\":\"08:00-19:00\",\"BULUNDUĞU İLÇE\":\"EYÜP\",\"BOYLAM\":\"28.9397962457675\",\"ENLEM\":\"41.0564862110081\"}","{\"OTOPARK ADI\":\"Eyüp İstanbul Caddesi 4\",\"LOKASYON ADI\":\"Eyüp İstanbul Caddes\",\"PARK TİPİ\":\"YOL ÜSTÜ\",\"PARK TİPİ TANIMI\":\"YOL ÜSTÜ\",\"PARK KAPASİTESİ\":40.0,\"ÇALIŞMA ZAMANI\":\"09:00-19:00\",\"BULUNDUĞU İLÇE\":\"EYÜP\",\"BOYLAM\":\"28.8898819017231\",\"ENLEM\":\"41.1764729732221\"}","{\"OTOPARK ADI\":\"Alibeyköy Cep Otogarı Otobüs Otoparkı\",\"LOKASYON ADI\":\"Alibeyköy Cep Otogarı Otobüs Otopark\",\"PARK TİPİ\":\"AÇIK OTOPARK\",\"PARK TİPİ TANIMI\":\"AÇIK OTOPARK\",\"PARK KAPASİTESİ\":116.0,\"ÇALIŞMA ZAMANI\":\"24 Saat\",\"BULUNDUĞU İLÇE\":\"EYÜP\",\"BOYLAM\":\"28.9449815819485\",\"ENLEM\":\"41.0877762255869\"}","{\"OTOPARK ADI\":\"Eyüp Pierloti Caddesi 1\",\"LOKASYON ADI\":\"Eyüp Pierloti Caddes\",\"PARK TİPİ\":\"YOL ÜSTÜ\",\"PARK TİPİ TANIMI\":\"YOL ÜSTÜ\",\"PARK KAPASİTESİ\":40.0,\"ÇALIŞMA ZAMANI\":\"08:00-00:00\",\"BULUNDUĞU İLÇE\":\"EYÜP\",\"BOYLAM\":\"28.9330016712335\",\"ENLEM\":\"41.0541552941076\"}","{\"OTOPARK ADI\":\"Feshane P+R Açık Otoparkı\",\"LOKASYON ADI\":\"Feshane P+R Açık Otopark\",\"PARK TİPİ\":\"AÇIK OTOPARK\",\"PARK TİPİ TANIMI\":\"AÇIK OTOPARK\",\"PARK KAPASİTESİ\":200.0,\"ÇALIŞMA ZAMANI\":\"24 Saat\",\"BULUNDUĞU İLÇE\":\"EYÜP\",\"BOYLAM\":\"28.9376096544914\",\"ENLEM\":\"41.046326666597\"}","{\"OTOPARK ADI\":\"Alibeyköy Cep Otogarı P+R\",\"LOKASYON ADI\":\"Alibeyköy Cep Otogarı P+\",\"PARK TİPİ\":\"AÇIK OTOPARK\",\"PARK TİPİ TANIMI\":\"AÇIK OTOPARK\",\"PARK KAPASİTESİ\":88.0,\"ÇALIŞMA ZAMANI\":\"24 Saat\",\"BULUNDUĞU İLÇE\":\"EYÜP\",\"BOYLAM\":\"28.9422369003296\",\"ENLEM\":\"41.0878908883406\"}","{\"OTOPARK ADI\":\"Alibeyköy Yeşiltepe Zemin Altı Otoparkı\",\"LOKASYON ADI\":\"Alibeyköy Yeşiltepe Zemin Altı Otopark\",\"PARK TİPİ\":\"KAPALI OTOPARK\",\"PARK TİPİ TANIMI\":\"KAPALI OTOPARK\",\"PARK KAPASİTESİ\":159.0,\"ÇALIŞMA ZAMANI\":\"24 Saat\",\"BULUNDUĞU İLÇE\":\"EYÜP\",\"BOYLAM\":\"28.9384609099211\",\"ENLEM\":\"41.0793200794339\"}","{\"OTOPARK ADI\":\"Eyüpsultan Akşemsettin Mahallesi Zemin Altı Otoparkı\",\"LOKASYON ADI\":\"Eyüpsultan Akşemsettin Mahallesi Zemin Altı Otopark\",\"PARK TİPİ\":\"KAPALI OTOPARK\",\"PARK TİPİ TANIMI\":\"KAPALI OTOPARK\",\"PARK KAPASİTESİ\":110.0,\"ÇALIŞMA ZAMANI\":\"24 Saat\",\"BULUNDUĞU İLÇE\":\"EYÜP\",\"BOYLAM\":\"28.9258415975185\",\"ENLEM\":\"41.0850632353534\"}","{\"OTOPARK ADI\":\"Eyüp Silahtarağa Açık Otoparkı\",\"LOKasyon ADI\":\"Eyüp Silahtarağa Açık Otopark\",\"PARK TİPİ\":\"AÇIK OTOPARK\",\"PARK TİPİ TANIMI\":\"AÇIK OTOPARK\",\"PARK KAPASİTESİ\":350.0,\"ÇALIŞMA ZAMANI\":\"24 Saat\",\"BULUNDUĞU İLÇE\":\"EYÜP\",\"BOYLAM\":\"28.
# 3. Adım: Artık sütunlar doğru olduğu için kodunuzun geri kalanı hatasız çalışacaktır.
park_df['ENLEM'] = pd.to_numeric(park_df['ENLEM'])
park_df['BOYLAM'] = pd.to_numeric(park_df['BOYLAM'])
park_df['PARK KAPASİTESİ'] = pd.to_numeric(park_df['PARK KAPASİTESİ'])

# Sonucu kontrol edelim
print(park_df.head())
print("\nVeri Tipleri:")
print(park_df.dtypes)
# Out:
#                              OTOPARK ADI  \
# 0  Alibeyköy Cep Otogarı Otobüs Otoparkı
# 1              Alibeyköy Cep Otogarı P+R
# 2                       Eyüp Tekke Parkı
# 3                Eyüp İstanbul Caddesi 4
# 4  Alibeyköy Cep Otogarı Otobüs Otoparkı
#
#                            LOKASYON ADI     PARK TİPİ PARK TİPİ TANIMI  \
# 0  Alibeyköy Cep Otogarı Otobüs Otopark  AÇIK OTOPARK     AÇIK OTOPARK
# 1              Alibeyköy Cep Otogarı P+  AÇIK OTOPARK     AÇIK OTOPARK
# 2                       Eyüp Tekke Park  AÇIK OTOPARK     AÇIK OTOPARK
# 3                  Eyüp İstanbul Caddes      YOL ÜSTÜ         YOL ÜSTÜ
# 4  Alibeyköy Cep Otogarı Otobüs Otopark  AÇIK OTOPARK     AÇIK OTOPARK
#
#    PARK KAPASİTESİ ÇALIŞMA ZAMANI BULUNDUĞU İLÇE     BOYLAM      ENLEM  \
# 0           5000.0        24 Saat           EYÜP  28.945155  41.087632
# 1             88.0        24 Saat           EYÜP  28.942388  41.088232
# ...

# %%
park_df['LOKASYON ADI'] = park_df['LOKASYON ADI'].combine_first(park_df['LOKasyon ADI'])

# 2. Artık işimiz kalmadığı için hatalı yazılmış 'LOKasyon ADI' sütununu silelim.
park_df.drop(columns=['LOKasyon ADI'], inplace=True)

# %%
park_df.isnull().sum()
# Out:
# OTOPARK ADI         0
# LOKASYON ADI        0
# PARK TİPİ           0
# PARK TİPİ TANIMI    0
# PARK KAPASİTESİ     0
# ÇALIŞMA ZAMANI      0
# BULUNDUĞU İLÇE      0
# BOYLAM              0
# ENLEM               0
# dtype: int64

# %%
park_df.to_csv("ispark_data.csv")

# %%
import pandas as pd
df=pd.read_csv("data/ispark_data.csv")

# %%
df.head()
# Out:
#    _id              PARK_NAME               LOCATION_NAME PARK_TYPE_ID  \
# 0    1  Vali Konağı Caddesi 1    Şişli Vali Konağı Caddes     YOL ÜSTÜ
# 1    2        Şakayık Sokak 1          Şişli Şakayık Soka     YOL ÜSTÜ
# 2    3  Hüsrev Gerede Sokak 1  Şişli Hüsrev Gerede Caddes     YOL ÜSTÜ
# 3    4    Sezai Selek Sokak 1         Seza-i Selek Caddes     YOL ÜSTÜ
# 4    5        Maçka Caddesi 1          Şişli Maçka Caddes     YOL ÜSTÜ
#
#   PARK_TYPE_DESC  CAPACITY_OF_PARK WORKING_TIME COUNTY_NAME  LONGITUDE  \
# 0       YOL ÜSTÜ                30  08:00-19:00       ŞİŞLİ  28.987975
# 1       YOL ÜSTÜ                50  08:00-19:00       ŞİŞLİ  28.995566
# 2       YOL ÜSTÜ                50  08:00-19:00       ŞİŞLİ  28.994976
# 3       YOL ÜSTÜ                50  08:00-19:00       ŞİŞLİ  28.995974
# 4       YOL ÜSTÜ                40  08:00-00:00       ŞİŞLİ  28.992955
#
#     LATITUDE
# 0  41.048823
# 1  41.049523
# 2  41.048390
# 3  41.053386
# 4  41.046630
